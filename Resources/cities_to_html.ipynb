# %%
# Dependencies and Setup
import pandas as pd

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")
# Display sample data
city_data_df.head()
# Out:
#    City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    atuona  -9.8000 -139.0333     24.87        70          46
# 1        1  tasiilaq  65.6145  -37.6368     -6.63        83          87
# 2        2   rikitea -23.1203 -134.9692     22.23        74          65
# 3        3  luderitz -26.6481   15.1594     17.06        81          95
# 4        4    madang  -5.2246  145.7966     26.56        82          87
#
#    Wind Speed Country        Date
# 0        5.20      PF  1667771566
# 1        2.46      GL  1667771567
# 2        6.06      PF  1667771279
# 3        2.53     NaN  1667771567
# 4        1.77      PG  1667771567

# %%
for col in city_data_df.columns:
    print(col)
# Out:
# City_ID
# City
# Lat
# Lng
# Max Temp
# Humidity
# Cloudiness
# Wind Speed
# Country
# Date

# %%
reordered_df = city_data_df[['City_ID','City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Date']].copy()
reordered_df.head()
# Out:
#    City_ID      City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    atuona      PF  -9.8000 -139.0333     24.87        70
# 1        1  tasiilaq      GL  65.6145  -37.6368     -6.63        83
# 2        2   rikitea      PF -23.1203 -134.9692     22.23        74
# 3        3  luderitz     NaN -26.6481   15.1594     17.06        81
# 4        4    madang      PG  -5.2246  145.7966     26.56        82
#
#    Cloudiness  Wind Speed        Date
# 0          46        5.20  1667771566
# 1          87        2.46  1667771567
# 2          65        6.06  1667771279
# 3          95        2.53  1667771567
# 4          87        1.77  1667771567

# %%
html = reordered_df.to_html(index=False)
print(html)

file = open("cities_html.html","w")
file.write(html)
file.close()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>atuona</td>
#       <td>PF</td>
#       <td>-9.8000</td>
#       <td>-139.0333</td>
#       <td>24.87</td>
#       <td>70</td>
#       <td>46</td>
#       <td>5.20</td>
#       <td>1667771566</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>tasiilaq</td>
#       <td>GL</td>
#       <td>65.6145</td>
#       <td>-37.6368</td>
#       <td>-6.63</td>
#       <td>83</td>
#       <td>87</td>
#       <td>2.46</td>
#       <td>1667771567</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>rikitea</td>
#       <td>PF</td>
#       <td>-23.1203</td>
# ...
